# %%
import googlemaps
import json
API_KEY = "AIzaSyAQCOr2z_gBhaKfuniDbEJI9DNleVDFbdk"

map_client = googlemaps.Client(API_KEY)
work_place_address = ("15.23264100789848, 77.57046095786329")
distance = 1000

response =  map_client.places_nearby(
    location = work_place_address,
    radius = distance
    )
print(response)
# Out:
# {'html_attributions': [], 'next_page_token': 'Aap_uECk15tVOH4CjyECzrdCfiLOM_swsmdwWTHQGBt1pWI9hJmoyV9L9ZBxWF7zcCPNpVV6RPQA1W_ix219Z_eVguXIa3Zj-rc1UdcY1UVKubIyqUAR2QnEFF7whnCYvk6CY_ORLAvPocFRQWcgjrqd_6VMl5RF3BPm-IOnlXj0wIlNH8_bWKE5Zqk08UQYksw5kxDj1lB-JLZmDc1Qf0kE5c-41fHOsV7B02t6xa58yZxWzOb8ls70cL-w8ZePxsaQBLgv8UXm7XmnRsK8M7zadgif0DQHc0_IabhywRd7uwsPoSFyyeTFEnsK_ZhpW0HdDeMWWrkK1mSRF-vsuDs6xe3-gfXjlhxRaREVzyNquJxSYzQ9KpCpqgWf4ChNFdRPuBFt4Ag9QUTfgOa3gQ_ENmilixYpRCxONMDYWxBTbXbP', 'results': [{'geometry': {'location': {'lat': 15.2316713, 'lng': 77.5705392}, 'viewport': {'northeast': {'lat': 15.23603647453388, 'lng': 77.57547132695908}, 'southwest': {'lat': 15.22709241317727, 'lng': 77.56506443165013}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Jonnagiri', 'photos': [{'height': 4160, 'html_attributions': ['<a 
# ...

# %%
results={}
places=[]
for i in response["results"]:
    places.append(i["name"])
results["places"]=places
results["location"]=work_place_address
results["distance"]=distance

# %%
with open("places.json","w") as f:
    json.dump(results,f)
